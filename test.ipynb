# %%
# from dataclasses import dataclass
import tbapy
import json
import pandas as pd

class tba_api_requests:
    
    def __init__(self, api_key_file_name):
        self.tba_api_key = open(api_key_file_name, 'r').read()
        self.tba = tbapy.TBA(self.tba_api_key)
        
    def tbapy_to_dict(self, json_data):
        s1 = json.dumps(json_data)
        data = json.loads(s1)
        
        return data
    
    def event_match_keys(self, event_key):
        return self.tba.event_matches(event_key, keys = True)
        
    def match_aggregate_data(self, match_key):
        
        json_data = self.tba.match(match_key)
        data = self.tbapy_to_dict(json_data)
        match_code = data['comp_level'] + str(data['match_number'])
        
        df = pd.DataFrame.from_dict(data['score_breakdown'])
        
        df = df.fillna('NO_DATA')
        df = df.transpose()
        
        column_list = ['totalPoints', 'matchCargoTotal',
                       'autoPoints', 'autoCargoPoints', 'autoCargoTotal', 'autoTaxiPoints',
                       'teleopPoints', 'teleopCargoPoints', 'teleopCargoTotal',
                       'endgamePoints', 'endgameRobot1', 'endgameRobot2', 'endgameRobot3']
        
        df = df[column_list]
        
        df['Robot1'] = [int(data['alliances'][x]['team_keys'][0][3:]) for x in df.index]
        df['Robot2'] = [int(data['alliances'][x]['team_keys'][1][3:]) for x in df.index]
        df['Robot3'] = [int(data['alliances'][x]['team_keys'][2][3:]) for x in df.index]
        
        df['match_number'] = data['match_number']
        df['comp_level'] = data['comp_level']
        df['alliance_color'] = df.index
                
        df = df.rename(index={
            'blue' : f'{match_code}_blue',
            'red': f'{match_code}_red'})

        return df
    
    def event_aggregate_data(self, event_key):
    
        match_keys = self.event_match_keys(event_key)
        filtered_match_keys = filter(lambda key: 'qm' in key, match_keys)
        filtered_match_keys = list(filtered_match_keys)
    
        df = self.match_aggregate_data(filtered_match_keys[0])

        for match in filtered_match_keys[1:]:
            df = pd.concat([df, self.match_aggregate_data(match)])

        return df

# %%
# from numpy import isin


l = tba_api_requests('tba_api_key.txt')
l.event_aggregate_data('2022varr')


# match_keys = l.event_match_keys('2022varr')
# # match_keys.sort()
# filtered_match_keys = filter(lambda key: 'qm' in key, match_keys)
# filtered_match_keys = list(filtered_match_keys)
# # for match in match_keys:
# #     if match.contains
    
# print(filtered_match_keys)

# h = l.match_aggregate_data(filtered_match_keys[0])

# for match in filtered_match_keys[1:]:
# 	h = pd.concat([h, l.match_aggregate_data(match)])
 
 
# h

# h.transpose()
# Out:
#           totalPoints matchCargoTotal autoPoints autoCargoPoints  \
# qm1_blue           69              20         22              16
# qm1_red            41              10         10               6
# qm10_blue          15               4          2               0
# qm10_red           58              15         14               8
# qm11_blue          21               3          8               2
# qm11_red           46              14         16              10
# qm12_blue          52              19          4               0
# qm12_red           81              27         18              12
# qm13_blue          41              13         12               6
# qm13_red           68              21         18              14
# qm14_blue          60              23         14              12
# qm14_red           75              24         26              20
# qm15_blue          40              12         30              28
# qm15_red           54              14         14               8
# qm16_blue          65              18         12               6
# qm16_red           42               9         26              20
# qm17_blue          35              10         12               8
# qm17_red           72              26         22              16
# qm18_blue          58               4         14               8
# qm18_red           58              11         26              20
# qm19_blue          93              31         10               8
# qm19_red           62              24          8               6
# qm2_blue           44              15         10               4
# qm2_red            94              31         28              22
# qm20_blue          75              21         12               8
# qm20_red           48              14         18              14
# qm21_blue          43              18         20              14
# qm21_red           58              21         26              20
# qm22_blue          56              21         16              10
# qm22_red           63              19          8               4
# qm23_blue          30              10          8               4
# qm23_red          115              31         22              16
# qm24_blue          95              35         16              12
# qm24_red           72              16         14               8
# qm25_blue          99              35         18              12
# qm25_red           42              20         12               6
# qm26_blue          37              13         14               8
# qm26_red           29               3          4               0
# qm27_blue          90              24         20              14
# qm27_red           75              20         18              14
# qm28_blue          41               8         16              10
# qm28_red          133              41         30              24
# qm29_blue         102              39         18              12
# qm29_red           48              18         20              14
# qm3_blue           39              15         14               8
# qm3_red            28               7          4               0
# qm30_blue          68              19         14               8
# qm30_red           95              25         28              22
# qm4_blue           20               6          4               0
# qm4_red            41               9          6               4
# qm5_blue           57              20         14               8
# qm5_red            54              22         14               8
# qm6_blue           49              18         22              16
# qm6_red            93              23         20              14
# qm7_blue           20               7          6               2
# qm7_red            66              18         10               4
# qm8_blue           55              16         14               8
# qm8_red            43              13          8               2
# qm9_blue           75              18         26              20
# qm9_red            51              21         10               4
#
#           autoCargoTotal autoTaxiPoints teleopPoints teleopCargoPoints  \
# qm1_blue               4              6           47                32
# qm1_red                2              4           23                 8
# qm10_blue              0              2           13                 7
# qm10_red               2              6           40                24
# qm11_blue              1              6            9                 3
# qm11_red               4              6           22                16
# qm12_blue              0              4           44                38
# qm12_red               3              6           63                47
# qm13_blue              2              6           29                14
# qm13_red               4              4           46                34
# qm14_blue              3              2           46                40
# qm14_red               5              6           49                28
# qm15_blue              7              2           10                10
# qm15_red               2              6           36                24
# qm16_blue              2              6           45                24
# qm16_red               5              6           12                 6
# qm17_blue              3              4           23                13
# qm17_red               4              6           46                42
# qm18_blue              2              6           44                 4
# qm18_red               5              6           24                12
# qm19_blue              2              2           83                58
# qm19_red               2              2           50                40
# qm2_blue               1              6           34                28
# qm2_red                6              6           66                50
# qm20_blue              2              4           63                38
# qm20_red               4              4           26                10
# qm21_blue              4              6           23                23
# qm21_red               6              6           32                26
# qm22_blue              3              6           40                24
# qm22_red               1              4           51                36
# qm23_blue              1              4           18                18
# qm23_red               4              6           89                53
# qm24_blue              3              4           75                63
# qm24_red               2              6           58                27
# qm25_blue              4              6           81                60
# qm25_red               2              6           30                24
# qm26_blue              3              6           23                11
# qm26_red               0              4           21                 6
# qm27_blue              4              6           58                33
# qm27_red               4              4           57                30
# qm28_blue              3              6           21                 9
# qm28_red               6              6           95                68
# qm29_blue              3              6           84                63
# qm29_red               4              6           28                22
# qm3_blue               2              6           25                25
# qm3_red                0              4           20                14
# qm30_blue              2              6           50                34
# qm30_red               6              6           67                37
# qm4_blue               0              4           12                12
# qm4_red                1              2           31                16
# qm5_blue               3              6           39                25
# qm5_red                2              6           40                40
# qm6_blue               4              6           27                27
# qm6_red                4              6           73                37
# qm7_blue               1              4            6                 6
# qm7_red                1              6           44                32
# qm8_blue               2              6           41                27
# qm8_red                1              6           35                14
# qm9_blue               5              6           37                25
# qm9_red                1              6           29                29
#
#           teleopCargoTotal endgamePoints endgameRobot1 endgameRobot2  \
# qm1_blue                16            15     Traversal          None
# qm1_red                  8            15          None          None
# qm10_blue                4             6          None           Mid
# qm10_red                13            16          None           Mid
# qm11_blue                2             6           Mid          None
# qm11_red                10             6           Mid          None
# qm12_blue               19             6          None           Mid
# qm12_red                24            16           Low           Mid
# qm13_blue               11            15          None     Traversal
# qm13_red                17            12          None           Mid
# qm14_blue               20             6           Mid          None
# qm14_red                19            21           Mid     Traversal
# qm15_blue                5             0          None          None
# qm15_red                12            12           Mid          None
# qm16_blue               16            21     Traversal          None
# qm16_red                 4             6          None          None
# qm17_blue                7            10          None          None
# qm17_red                22             4          None           Low
# qm18_blue                2            40     Traversal     Traversal
# qm18_red                 6            12          None           Mid
# qm19_blue               29            25          None     Traversal
# qm19_red                22            10          None          None
# qm2_blue                14             6           Mid          None
# qm2_red                 25            16           Mid          High
# qm20_blue               19            25          High     Traversal
# qm20_red                10            16          High          None
# qm21_blue               14             0          None          None
# qm21_red                15             6           Mid          None
# qm22_blue               18            16           Mid           Low
# qm22_red                18            15          None     Traversal
# qm23_blue                9             0          None          None
# qm23_red                27            36     Traversal           Mid
# qm24_blue               32            12           Mid           Mid
# qm24_red                14            31           Mid          High
# qm25_blue               31            21          None           Mid
# qm25_red                18             6          None           Mid
# qm26_blue               10            12           Mid           Mid
# qm26_red                 3            15          None     Traversal
# qm27_blue               20            25          None     Traversal
# qm27_red                16            27           Mid     Traversal
# qm28_blue                5            12           Mid          None
# qm28_red                35            27           Mid     Traversal
# qm29_blue               36            21     Traversal           Mid
# qm29_red                14             6          None          None
# qm3_blue                13             0          None          None
# qm3_red                  7             6           Mid          None
# qm30_blue               17            16          High          None
# qm30_red                19            30     Traversal          None
# qm4_blue                 6             0          None          None
# qm4_red                  8            15          None          None
# qm5_blue                17            14          None           Low
# qm5_red                 20             0          None          None
# qm6_blue                14             0          None          None
# qm6_red                 19            36     Traversal           Mid
# qm7_blue                 6             0          None          None
# qm7_red                 17            12          None           Mid
# qm8_blue                14            14           Low          High
# qm8_red                 12            21     Traversal          None
# qm9_blue                13            12          None           Mid
# qm9_red                 20             0          None          None
#
#           endgameRobot3  Robot1  Robot2  Robot3  match_number comp_level  \
# qm1_blue           None     422    2363    2890             1         qm
# qm1_red       Traversal     900    9998    3737             1         qm
# qm10_blue          None    4561    5804    2890            10         qm
# qm10_red           High    9991     384    1793            10         qm
# qm11_blue          None     435    3359    9998            11         qm
# qm11_red           None    1086     900    9999            11         qm
# qm12_blue          None     836    1599    6194            12         qm
# qm12_red            Mid    3136     122    1908            12         qm
# qm13_blue          None    5804    3737     977            13         qm
# qm13_red            Mid     401     619    1793            13         qm
# qm14_blue          None     384    4561     339            14         qm
# qm14_red           None    1610     422    2028            14         qm
# qm15_blue          None    8590     346    2363            15         qm
# qm15_red            Mid    2890    9991    2642            15         qm
# qm16_blue           Mid    3737    1793    3136            16         qm
# qm16_red            Mid     122    6194    1086            16         qm
# qm17_blue          High     339    9999     619            17         qm
# qm17_red           None    1908     384    5804            17         qm
# qm18_blue          High    3359    2890     346            18         qm
# qm18_red            Mid    1599    2028    2363            18         qm
# qm19_blue          High    9998     401     836            19         qm
# qm19_red           High    2642     435    4561            19         qm
# qm2_blue           None    1086    3136    8590             2         qm
# qm2_red            None     384     401    9999             2         qm
# qm20_blue          None     977     900     422            20         qm
# qm20_red            Mid    1610    8590    9991            20         qm
# qm21_blue          None    9999    3136    1599            21         qm
# qm21_red           None    1793    2363     339            21         qm
# qm22_blue           Mid     619    1908    3737            22         qm
# qm22_red           None    4561     346    9998            22         qm
# qm23_blue          None    2028    8590     900            23         qm
# qm23_red      Traversal    5804    1086     836            23         qm
# qm24_blue          None     122     422     384            24         qm
# qm24_red      Traversal     977    2642    3359            24         qm
# qm25_blue     Traversal     401     435    9991            25         qm
# qm25_red           None    6194    2890    1610            25         qm
# qm26_blue          None     900    1793    1599            26         qm
# qm26_red           None    9998     619    8590            26         qm
# qm27_blue          High    2642    3737     422            27         qm
# qm27_red            Mid    2028    5804    3136            27         qm
# qm28_blue           Mid    1908    6194     435            28         qm
# qm28_red            Mid    2363     977     384            28         qm
# qm29_blue          None     836    1610    4561            29         qm
# qm29_red            Mid    2890    9999     122            29         qm
# qm3_blue           None     435    2028     122             3         qm
# qm3_red            None     619    9991     346             3         qm
# qm30_blue           Mid    9991    3359    1086            30         qm
# qm30_red      Traversal     346     339     401            30         qm
# qm4_blue           None     339    1599    2642             4         qm
# qm4_red       Traversal    6194    4561     977             4         qm
# qm5_blue           High    1793    1610    5804             5         qm
# qm5_red            None    3359     836    1908             5         qm
# qm6_blue           None    2363     122     900             6         qm
# qm6_red       Traversal     422    1086     401             6         qm
# qm7_blue           None    9999    9998    6194             7         qm
# qm7_red             Mid     346     977    2028             7         qm
# qm8_blue           None    8590     836     435             8         qm
# qm8_red             Mid    3737     339    3359             8         qm
# qm9_blue            Mid    3136    2642     619             9         qm
# qm9_red            None    1599    1908    1610             9         qm
#
#           alliance_color
# qm1_blue            blue
# qm1_red              red
# qm10_blue           blue
# qm10_red             red
# qm11_blue           blue
# qm11_red             red
# qm12_blue           blue
# qm12_red             red
# qm13_blue           blue
# qm13_red             red
# qm14_blue           blue
# qm14_red             red
# qm15_blue           blue
# qm15_red             red
# qm16_blue           blue
# qm16_red             red
# qm17_blue           blue
# qm17_red             red
# qm18_blue           blue
# qm18_red             red
# qm19_blue           blue
# qm19_red             red
# qm2_blue            blue
# qm2_red              red
# qm20_blue           blue
# qm20_red             red
# qm21_blue           blue
# qm21_red             red
# qm22_blue           blue
# qm22_red             red
# qm23_blue           blue
# qm23_red             red
# qm24_blue           blue
# qm24_red             red
# qm25_blue           blue
# qm25_red             red
# qm26_blue           blue
# qm26_red             red
# qm27_blue           blue
# qm27_red             red
# qm28_blue           blue
# qm28_red             red
# qm29_blue           blue
# qm29_red             red
# qm3_blue            blue
# qm3_red              red
# qm30_blue           blue
# qm30_red             red
# qm4_blue            blue
# qm4_red              red
# qm5_blue            blue
# qm5_red              red
# qm6_blue            blue
# qm6_red              red
# qm7_blue            blue
# qm7_red              red
# qm8_blue            blue
# qm8_red              red
# qm9_blue            blue
# qm9_red              red
